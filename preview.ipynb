# %%
import pandas as pd

# %%
PATH = './data/data.csv'

# %%
df = pd.read_csv(PATH, sep='|', encoding='cp1252', dtype={
    'UBIGEO_DISTRITO': 'string',
    'COD_UNIDAD_EJECUTORA': 'string',
    'COD_IPRESS': 'string',
    'COD_SERVICIO': 'string'
})
df.head(10)
# Out:
#     AÑO  MES       REGION PROVINCIA UBIGEO_DISTRITO DISTRITO  \
# 0  2020    9  LA LIBERTAD     PATAZ          130808   PARCOY
# 1  2020    9  LA LIBERTAD     PATAZ          130808   PARCOY
# 2  2020    9  LA LIBERTAD     PATAZ          130808   PARCOY
# 3  2020    9  LA LIBERTAD     PATAZ          130808   PARCOY
# 4  2020    9  LA LIBERTAD     PATAZ          130808   PARCOY
# 5  2020    9  LA LIBERTAD     PATAZ          130808   PARCOY
# 6  2020    9  LA LIBERTAD     PATAZ          130808   PARCOY
# 7  2020    9  LA LIBERTAD     PATAZ          130808   PARCOY
# 8  2020    9  LA LIBERTAD     PATAZ          130808   PARCOY
# 9  2020    9  LA LIBERTAD     PATAZ          130808   PARCOY
#
#   COD_UNIDAD_EJECUTORA       DESC_UNIDAD_EJECUTORA  COD_IPRESS  \
# 0                 0845  REGION LA LIBERTAD - SALUD  0000005387
# 1                 0845  REGION LA LIBERTAD - SALUD  0000005387
# 2                 0845  REGION LA LIBERTAD - SALUD  0000016974
# ...

# %%
df.shape
# Out:
# (5243338, 17)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5243338 entries, 0 to 5243337
# Data columns (total 17 columns):
#  #   Column                 Dtype
# ---  ------                 -----
#  0   AÑO                    int64
#  1   MES                    int64
#  2   REGION                 object
#  3   PROVINCIA              object
#  4   UBIGEO_DISTRITO        string
#  5   DISTRITO               object
#  6   COD_UNIDAD_EJECUTORA   string
#  7   DESC_UNIDAD_EJECUTORA  object
#  8   COD_IPRESS             string
#  9   IPRESS                 object
#  10  NIVEL_EESS             object
#  11  PLAN_DE_SEGURO         object
#  12  COD_SERVICIO           string
#  13  DESC_SERVICIO          object
#  14  SEXO                   object
#  15  GRUPO_EDAD             object
#  16  ATENCIONES             int64
# dtypes: int64(3), object(10), string(4)
# memory usage: 680.1+ MB

# %%
df.describe()
# Out:
#              AÑO           MES    ATENCIONES
# count  5243338.0  5.243338e+06  5.243338e+06
# mean      2020.0  6.064599e+00  7.192736e+00
# std          0.0  3.675150e+00  2.774484e+01
# min       2020.0  1.000000e+00  1.000000e+00
# 25%       2020.0  3.000000e+00  1.000000e+00
# 50%       2020.0  6.000000e+00  3.000000e+00
# 75%       2020.0  9.000000e+00  7.000000e+00
# max       2020.0  1.200000e+01  9.825000e+03

# %%
print(df['REGION'].unique())
# Out:
# ['LA LIBERTAD' 'LAMBAYEQUE' 'LIMA METROPOLITANA' 'LIMA REGION' 'LORETO'
#  'MADRE DE DIOS' 'MOQUEGUA' 'PASCO' 'PIURA' 'PUNO' 'SAN MARTÍN' 'TACNA'
#  'TUMBES' 'UCAYALI' 'AMAZONAS' 'ÁNCASH' 'APURÍMAC' 'AREQUIPA' 'AYACUCHO'
#  'CAJAMARCA' 'CALLAO' 'CUSCO' 'HUANCAVELICA' 'HUÁNUCO' 'ICA' 'JUNÍN']

# %%
print(df['NIVEL_EESS'].unique())
# Out:
# ['I' 'II' 'III' '0']
